# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in c:\programming\anaconda\lib\site-packages (2.25.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\programming\anaconda\lib\site-packages (from requests) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\programming\anaconda\lib\site-packages (from requests) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programming\anaconda\lib\site-packages (from requests) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\programming\anaconda\lib\site-packages (from requests) (2.10)

# %%
# !pip install BeautifulSoup4
# Out:
# Requirement already satisfied: BeautifulSoup4 in c:\programming\anaconda\lib\site-packages (4.9.3)
# Requirement already satisfied: soupsieve>1.2 in c:\programming\anaconda\lib\site-packages (from BeautifulSoup4) (2.2.1)

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

num_list = []
res = requests.get('https://dhlottery.co.kr/common.do?method=main')
soup = BeautifulSoup(res.content, 'html.parser')
result = soup.select('.ball_645')

#
for num in result :
    print(num.text, end=' / ') 
    num_list.append(num.text)
    
#
num_list
df = pd.DataFrame({'num':num_list})

#change data type to int
df = df.astype(int)

df
# Out:
# 9 / 11 / 30 / 31 / 41 / 44 / 33 /
#    num
# 0    9
# 1   11
# 2   30
# 3   31
# 4   41
# 5   44
# 6   33
